# %% [markdown]
# # Interaction between Spending and other factors
# **Van Ha TRAN**

# %%
git init
git add exploration.ipynb
git commit -m "Create notebook"
git remote add origin <https://github.com/vhatr12/marketing.git>
git push -u origin main
